# %%
import matplotlib.pyplot as plt
import math
from random import randint
# trignometric
x = [i-100 for i in range(200)]
y = [0.0 for i in range(200)]
k = 100
for i in range(k):
    ck ,m,n= randint(-10,10),randint(-10,10),randint(-10,10)
    print (ck,m,n)
    for j in range(len(x)):
        sinx , cosx = math.sin(x[j]) , math.cos(x[j])
        #print(sinx,cosx)
        psinx , pcosx = math.pow(sinx,int(m)) , math.pow(cosx,int(n))
        print(sinx,cosx,m,n)
        #print(psinx,pcosx)
        #y[j] += ck*psinx*pcosx

plt.plot(x,y)
plt.show()
# Out:
# 3 -1 -4
# 0.5063656411097588 0.8623188722876839 -1 -4
# 0.9992068341863537 0.0398208803931389 -1 -4
# 0.5733818719904229 -0.8192882452914593 -1 -4
# -0.3796077390275217 -0.9251475365964139 -1 -4
# -0.9835877454343449 -0.18043044929108396 -1 -4
# -0.683261714736121 0.7301735609948197 -1 -4
# 0.24525198546765434 0.9694593666699876 -1 -4
# 0.9482821412699473 0.31742870151970165 -1 -4
# 0.7794660696158047 -0.626444447910339 -1 -4
# -0.10598751175115685 -0.9943674609282015 -1 -4
# -0.8939966636005579 -0.4480736161291701 -1 -4
# -0.8600694058124533 0.5101770449416689 -1 -4
# -0.03539830273366068 0.9993732836951247 -1 -4
# 0.8218178366308225 0.569750334265312 -1 -4
# 0.9234584470040598 -0.38369844494974187 -1 -4
# 0.1760756199485871 -0.9843766433940419 -1 -4
# -0.7331903200732922 -0.6800234955873388 -1 -4
# -0.9683644611001854 0.24954011797333814 -1 -4
# -0.31322878243308516 0.9496776978825432 -1 -4
# 0.6298879942744539 0.7766859820216312 -1 -4
# ...
